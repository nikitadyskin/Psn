# %%
import pandas as pd
import os 

path=r'C:\Users\nikit\OneDrive\Desktop\Psn\trab_final\excelfiles'
df = pd.read_excel(os.path.join(path,'O seu municipio em numeros! Abrantes.xls'))

# Limpeza do Data Frame resultante
df=df[6:78]
df=df.drop(['Unnamed: 1','Unnamed: 3','Unnamed: 5','Unnamed: 6'],axis=1)#axis 1 porque é para eleminar coluna
df.columns=['Municipio']+df.loc[7].tolist()[1:]
df.loc[6]=['Ano',2010,2019]
df=df.drop(7)
df=df.transpose()
df.columns=df.loc['Municipio']
df=df.drop(['Municipio'])
    
print('primeira parte foi lida')
# Out:
# primeira parte foi lida

# %%
f=open(r'C:\Users\nikit\OneDrive\Desktop\Psn\trab_final\excelfiles\municipios2.txt')
listMun=[m.strip() for m in f.readlines()]

for mun in listMun:
    df1 = pd.read_excel(os.path.join(path,f'O seu municipio em numeros! {mun}.xls'))
    df1=df1[6:78]
    df1=df1.drop(['Unnamed: 2','Unnamed: 4','Unnamed: 5','Unnamed: 6'],axis=1)#axis 1 porque é para eleminar coluna
    df1.columns=['Municipio']+df1.loc[7].tolist()[1:]
    df1.loc[6]=['Ano',2010,2019]
    df1=df1.drop(7)
    df1=df1.transpose()
    df1.columns=df1.loc['Municipio']
    df1=df1.drop(['Municipio'])
    df1.columns=df.columns
    df=df.append(df1)
    
    
df.columns=[c.strip() for c in df.columns]

df=df.drop(['Empresas não financeiras','€, milhares','Superfície em km2'],axis=1)



for c in df.columns:
    if df[c].isnull().all():
        df=df.drop(c,axis=1)
        
df
# Out:
#             Ano População residente Densidade populacional Jovens (%)  \
# Portugal   2010            10573100                      0       15.2
# Portugal   2019            10286263                  111.5       13.6
# Abrantes   2010               39637                      0       12.8
# Abrantes   2019               35254                   49.3       10.9
# Águeda     2010               47875                      0       13.9
# ...         ...                 ...                    ...        ...
# Viseu      2019               97120                  191.5       13.5
# Vizela     2010               23739                      0         17
# Vizela     2019               23869                  966.3       13.2
# Vouzela    2010               10656                      0       12.7
# Vouzela    2019                9640                   49.8        9.7
#
#           População em idade activa (%) Idosos (%) Índice de envelhecimento  \
# Portugal                           66.3       18.5                      122
# Portugal                           64.4         22                      161
# Abrantes                           61.6       25.6                      200
# Abrantes                           60.3       28.8                      264
# Águeda                             67.3       18.8                      135
# ...                                 ...        ...                      ...
# Viseu                              65.3       21.2                      157
# Vizela                             72.1       10.9                       64
# Vizela                             71.6       15.3                      116
# Vouzela                            60.7       26.6                      210
# Vouzela                              61       29.2                      300
#
#           População estrangeira (2)  \
# Portugal                     443055
# Portugal                     588976
# Abrantes                        652
# Abrantes                        497
# Águeda                         1176
# ...                             ...
# Viseu                          2624
# Vizela                          140
# Vizela                          191
# Vouzela                          92
# Vouzela                         100
#
#           População estrangeira em % da população residente (2)  \
# Portugal                                                 4.2
# Portugal                                                 5.7
# Abrantes                                                 1.6
# Abrantes                                                 1.4
# Águeda                                                   2.5
# ...                                                      ...
# Viseu                                                    2.7
# Vizela                                                   0.6
# Vizela                                                   0.8
# Vouzela                                                  0.9
# Vouzela                                                    1
#
#           Nascimentos (3)  ... Trabalhadores da Administração Pública Local  \
# Portugal                0  ...                                       135527
# Portugal            86579  ...                                       128094
# Abrantes                0  ...                                          407
# Abrantes              201  ...                                          368
# Águeda                  0  ...                                          436
# ...                   ...  ...                                          ...
# Viseu                 777  ...                                          814
# Vizela                  0  ...                                          311
# Vizela                203  ...                                          260
# Vouzela                 0  ...                                          179
# Vouzela                65  ...                                          202
#
#           Despesas da Câmara Municipal (7) Receitas da Câmara Municipal (8)  \
# Portugal                       7.18198e+06                      7.24744e+06
# Portugal                                 0                                0
# Abrantes                             23972                          25909.4
# Abrantes                                 0                                0
# Águeda                               27661                          27699.6
# ...                                    ...                              ...
# Viseu                                    0                                0
# Vizela                             11371.3                          11491.1
# Vizela                                   0                                0
# Vouzela                             9657.7                          10299.6
# Vouzela                                  0                                0
#
#           Saldo financeiro da Câmara Municipal  \
# Portugal                                 65461
# Portugal                                     0
# Abrantes                                  1937
# Abrantes                                     0
# Águeda                                      39
# ...                                        ...
# Viseu                                        0
# Vizela                                     120
# Vizela                                       0
# Vouzela                                    642
# Vouzela                                      0
#
#           Transferências recebidas no total das receitas da Câmara Municipal (%)  \
# Portugal                                                  49
# Portugal                                                   0
# Abrantes                                                63.8
# Abrantes                                                   0
# Águeda                                                    54
# ...                                                      ...
# Viseu                                                      0
# Vizela                                                  66.4
# Vizela                                                     0
# Vouzela                                                 77.3
# Vouzela                                                    0
#
#           Crimes registados pelas polícias por mil habitantes  \
# Portugal                                                40.1
# Portugal                                                32.6
# Abrantes                                                32.4
# Abrantes                                                21.6
# Águeda                                                  33.8
# ...                                                      ...
# Viseu                                                   25.8
# Vizela                                                  38.3
# Vizela                                                  17.8
# Vouzela                                                   31
# Vouzela                                                   23
#
#           Consumo de energia eléctrica por habitante (kWh)  \
# Portugal                                            4776.8
# Portugal                                                 0
# Abrantes                                            4075.9
# Abrantes                                                 0
# Águeda                                              5421.9
# ...                                                    ...
# Viseu                                                    0
# Vizela                                              3906.8
# Vizela                                                   0
# Vouzela                                             2937.2
# Vouzela                                                  0
#
#           Resíduos urbanos recolhidos selectivamente por habitante (kg)  \
# Portugal                                                76.2
# Portugal                                               109.6
# Abrantes                                                66.2
# Abrantes                                                65.1
# Águeda                                                  52.4
# ...                                                      ...
# Viseu                                                   64.5
# Vizela                                                  42.1
# Vizela                                                  66.7
# Vouzela                                                 26.1
# Vouzela                                                 45.5
#
#           Despesas do município em ambiente (%) Alojamentos turísticos (6)
# Portugal                                      8                       2011
# Portugal                                      0                       6833
# Abrantes                                      5                          4
# Abrantes                                      0                         14
# Águeda                                        5                          6
# ...                                         ...                        ...
# Viseu                                         0                         30
# Vizela                                        4                          0
# Vizela                                        0                          3
# Vouzela                                       7                          1
# Vouzela                                       0                          9
#
# [618 rows x 55 columns]

# %%
# df.to_excel(os.path.join(path,'data_V1.xls'))

df.to_excel('data_V1.xls')
