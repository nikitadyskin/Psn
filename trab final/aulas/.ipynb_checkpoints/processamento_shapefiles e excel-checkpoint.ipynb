# %%
import geopandas as gpd 
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import matplotlib as mpl

shapefile=gpd.read_file(r'C:\Users\nikit\OneDrive\Desktop\ShapeFiles\gadm36_PRT.gpkg')
shapefile['join']=shapefile['NAME_1']+shapefile['NAME_2']
shp=shapefile.dissolve(by='join')
# Out:
# C:\Users\nikit\anaconda3\envs\geo_env\lib\site-packages\geopandas\geodataframe.py:577: RuntimeWarning: Sequential read of iterator was interrupted. Resetting iterator. This can negatively impact the performance.
#   for feature in features_lst:

# %%
exc=pd.read_excel(r'C:\Users\nikit\OneDrive\Desktop\PSn-main\excelfiles\data_V1.xls',index_col='Unnamed: 0')
exc.index=[v.strip() for v in exc.index]#faz lista dos distritos mas sem espaços nos nomes


munExcel=exc.drop('Portugal').index.unique().to_list()


munGeo=shp['NAME_2'].tolist()
munGeo

#for m in munExcel:
    #if m not in munGeo:
        #print('Falta',m)
#print('*******') 
#for m in munGeo:
    #if m not in munExcel:
        #print('Falta',m)
#ciclos servem para ver o que difere entre o shp e o exc       
        
shp.loc[shp['NAME_2']=='Ponte de Sôr','NAME_2']='Ponte de Sor'
shp.loc[shp['NAME_2']=='Praia da Vitória','NAME_2']='Vila da Praia da Vitória'
shp.loc[((shp['NAME_2']=='Calheta') & (shp['NAME_1']=='Azores')),'NAME_2']='Calheta [R.A.A.]'
shp.loc[((shp['NAME_2']=='Calheta') & (shp['NAME_1']=='Madeira')),'NAME_2']='Calheta [R.A.M.]'
shp.loc[((shp['NAME_2']=='Lagoa') & (shp['NAME_1']=='Azores')),'NAME_2']='Lagoa [R.A.A.]'


shp=shp.rename(columns={'NAME_1':'Distrito'})
shp.index=shp['NAME_2']

madeira=shp[shp['Distrito']=='Madeira'].index.to_list()
acores=shp[shp['Distrito']=='Azores'].index.to_list()
continente=shp[(shp['Distrito']!='Azores') & (shp['Distrito']!='Madeira')].index.to_list()
    
#len(continente)+len(madeira)+len(acores)#teste=308    

exc['Distrito']=shp['Distrito']
exc['geometry']=shp['geometry']

# %%
import random as rand

def printMap(df,area,title):
    cmap=plt.cm.rainbow
    
    ax = plt.gca()
    for m in area:
        muni=gpd.GeoDataFrame(df.loc[m].to_frame().T)
        value=rand.random()
        colorCode=mpl.colors.to_hex(cmap(value)[0:3])
        muni.plot(color=colorCode,ax=ax)
    plt.title(title)
    plt.show()
printMap(exc[exc['Ano']==2010],acores,'mapa dos Açores')
printMap(exc[exc['Ano']==2010],madeira,'mapa dos Madeira')   
printMap(exc[exc['Ano']==2010],continente,'mapa do Continente')

# %%
for i in exc:
    P1=exc['População residente']*exc['Jovens (%)']
    P2=exc['População residente']*exc['Idosos (%)']
    exc['Índice de envelhecimento new'] = ( P1 / P2 )



def printMap(df,area,title):
    cmap=plt.cm.rainbow
    
    ax = plt.gca()
    for m in area:
        muni=gpd.GeoDataFrame(df.loc[m].to_frame().T)
        muni
        value=exc.at[area,'A']
        #value=exc['Índice de envelhecimento new']
        colorCode=mpl.colors.to_hex(cmap(value)[0:3])
        muni.plot(color=colorCode,ax=ax)
    plt.title(title)
    plt.show()
printMap(exc[exc['Ano']==2010],acores,'mapa dos Açores')
printMap(exc[exc['Ano']==2010],madeira,'mapa dos Madeira')   
printMap(exc[exc['Ano']==2010],continente,'mapa do Continente')

#calcular o indice de envelhecimento de cada destrito e em vez de imprimir um random imprimir indice de envelhecimento do destrito com uma cor porpocional ao indice de emvelhecimento

#Fórmula de cálculo: IE = ( P1 ÷ P2 ) x 100;  em que

#P1: população com idade igual ou superior a 65 anos; e

#P2: população com idades compreendidas entre os 0 e os 14 anos.
# Out:
#            Ano  População residente  Densidade populacional  Jovens (%)  \
# Portugal  2010             10573100                     0.0        15.2
# Portugal  2019             10286263                   111.5        13.6
# Abrantes  2010                39637                     0.0        12.8
# Abrantes  2019                35254                    49.3        10.9
# Águeda    2010                47875                     0.0        13.9
# ...        ...                  ...                     ...         ...
# Viseu     2019                97120                   191.5        13.5
# Vizela    2010                23739                     0.0        17.0
# Vizela    2019                23869                   966.3        13.2
# Vouzela   2010                10656                     0.0        12.7
# Vouzela   2019                 9640                    49.8         9.7
#
#           População em idade activa (%)  Idosos (%)  Índice de envelhecimento  \
# Portugal                           66.3        18.5                       122
# Portugal                           64.4        22.0                       161
# Abrantes                           61.6        25.6                       200
# Abrantes                           60.3        28.8                       264
# Águeda                             67.3        18.8                       135
# ...                                 ...         ...                       ...
# Viseu                              65.3        21.2                       157
# Vizela                             72.1        10.9                        64
# Vizela                             71.6        15.3                       116
# Vouzela                            60.7        26.6                       210
# Vouzela                            61.0        29.2                       300
#
#           População estrangeira (2)  \
# Portugal                     443055
# Portugal                     588976
# Abrantes                        652
# Abrantes                        497
# Águeda                         1176
# ...                             ...
# Viseu                          2624
# Vizela                          140
# Vizela                          191
# Vouzela                          92
# Vouzela                         100
#
#           População estrangeira em % da população residente (2)  \
# Portugal                                                4.2
# Portugal                                                5.7
# Abrantes                                                1.6
# Abrantes                                                1.4
# Águeda                                                  2.5
# ...                                                     ...
# Viseu                                                   2.7
# Vizela                                                  0.6
# Vizela                                                  0.8
# Vouzela                                                 0.9
# Vouzela                                                 1.0
#
#           Nascimentos (3)  ...  Saldo financeiro da Câmara Municipal  \
# Portugal                0  ...                                 65461
# Portugal            86579  ...                                     0
# Abrantes                0  ...                                  1937
# Abrantes              201  ...                                     0
# Águeda                  0  ...                                    39
# ...                   ...  ...                                   ...
# Viseu                 777  ...                                     0
# Vizela                  0  ...                                   120
# Vizela                203  ...                                     0
# Vouzela                 0  ...                                   642
# Vouzela                65  ...                                     0
#
#           Transferências recebidas no total das receitas da Câmara Municipal (%)  \
# Portugal                                               49.0
# Portugal                                                0.0
# Abrantes                                               63.8
# Abrantes                                                0.0
# Águeda                                                 54.0
# ...                                                     ...
# Viseu                                                   0.0
# Vizela                                                 66.4
# Vizela                                                  0.0
# Vouzela                                                77.3
# Vouzela                                                 0.0
#
#           Crimes registados pelas polícias por mil habitantes  \
# Portugal                                               40.1
# Portugal                                               32.6
# Abrantes                                               32.4
# Abrantes                                               21.6
# Águeda                                                 33.8
# ...                                                     ...
# Viseu                                                  25.8
# Vizela                                                 38.3
# Vizela                                                 17.8
# Vouzela                                                31.0
# Vouzela                                                23.0
#
#           Consumo de energia eléctrica por habitante (kWh)  \
# Portugal                                            4776.8
# Portugal                                               0.0
# Abrantes                                            4075.9
# Abrantes                                               0.0
# Águeda                                              5421.9
# ...                                                    ...
# Viseu                                                  0.0
# Vizela                                              3906.8
# Vizela                                                 0.0
# Vouzela                                             2937.2
# Vouzela                                                0.0
#
#           Resíduos urbanos recolhidos selectivamente por habitante (kg)  \
# Portugal                                               76.2
# Portugal                                              109.6
# Abrantes                                               66.2
# Abrantes                                               65.1
# Águeda                                                 52.4
# ...                                                     ...
# Viseu                                                  64.5
# Vizela                                                 42.1
# Vizela                                                 66.7
# Vouzela                                                26.1
# Vouzela                                                45.5
#
#           Despesas do município em ambiente (%)  Alojamentos turísticos (6)  \
# Portugal                                      8                        2011
# Portugal                                      0                        6833
# Abrantes                                      5                           4
# Abrantes                                      0                          14
# Águeda                                        5                           6
# ...                                         ...                         ...
# Viseu                                         0                          30
# Vizela                                        4                           0
# Vizela                                        0                           3
# Vouzela                                       7                           1
# Vouzela                                       0                           9
#
#           Distrito                                           geometry  \
# Portugal       NaN                                               None
# Portugal       NaN                                               None
# Abrantes  Santarém  POLYGON ((-8.08080 39.27791, -8.08095 39.27792...
# Abrantes  Santarém  POLYGON ((-8.08080 39.27791, -8.08095 39.27792...
# Águeda      Aveiro  POLYGON ((-8.46218 40.50539, -8.46222 40.50544...
# ...            ...                                                ...
# Viseu        Viseu  POLYGON ((-8.00609 40.54715, -8.00596 40.54738...
# Vizela       Braga  POLYGON ((-8.27858 41.34796, -8.27836 41.34583...
# Vizela       Braga  POLYGON ((-8.27858 41.34796, -8.27836 41.34583...
# Vouzela      Viseu  POLYGON ((-8.12751 40.64027, -8.12772 40.64028...
# Vouzela      Viseu  POLYGON ((-8.12751 40.64027, -8.12772 40.64028...
#
#           Índice de envelhecimento new
# Portugal                      0.821622
# Portugal                      0.618182
# Abrantes                      0.500000
# Abrantes                      0.378472
# Águeda                        0.739362
# ...                                ...
# Viseu                         0.636792
# Vizela                        1.559633
# Vizela                        0.862745
# Vouzela                       0.477444
# Vouzela                       0.332192
#
# [618 rows x 58 columns]
